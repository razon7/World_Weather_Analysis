# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 741

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5d72d58579573842d248e5fadc6a7d3d

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]['description']
        city_country = city_weather["sys"]["country"]
        #iso standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc,
                          "Country": city_country,
                          "Date": city_date})

        
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jalu
# Processing Record 2 of Set 1 | srandakan
# Processing Record 3 of Set 1 | tasiilaq
# Processing Record 4 of Set 1 | santa cruz
# Processing Record 5 of Set 1 | geraldton
# Processing Record 6 of Set 1 | udachnyy
# Processing Record 7 of Set 1 | pacific grove
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | port alfred
# Processing Record 10 of Set 1 | lorengau
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | saskylakh
# Processing Record 13 of Set 1 | port hedland
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | moranbah
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 1 | cherskiy
# Processing Record 19 of Set 1 | rawson
# Processing Record 20 of Set 1 | mahebourg
# Processing Record 21 of Set 1 | kahului
# Processing Record 22 of Set 1 | sandakan
# Processing Record 23 of Set 1 | khatanga
# Processing Record 24 of Set 1 | barrow
# Processing Record 25 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 1 | nishihara
# Processing Record 27 of Set 1 | new norfolk
# Processing Record 28 of Set 1 | ilulissat
# Processing Record 29 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 30 of Set 1 | carnarvon
# Processing Record 31 of Set 1 | bluff
# Processing Record 32 of Set 1 | saint-philippe
# Processing Record 33 of Set 1 | avera
# Processing Record 34 of Set 1 | broome
# Processing Record 35 of Set 1 | calabozo
# Processing Record 36 of Set 1 | butaritari
# Processing Record 37 of Set 1 | russell
# Processing Record 38 of Set 1 | los llanos de aridane
# Processing Record 39 of Set 1 | tiksi
# Processing Record 40 of Set 1 | albert lea
# Processing Record 41 of Set 1 | gallup
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | tyukhtet
# Processing Record 44 of Set 1 | nanortalik
# Processing Record 45 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 1 | teknaf
# Processing Record 47 of Set 1 | pisco
# Processing Record 48 of Set 1 | hobart
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | mogadishu
# Processing Record 1 of Set 2 | alofi
# Processing Record 2 of Set 2 | hamilton
# Processing Record 3 of Set 2 | awassa
# Processing Record 4 of Set 2 | vanavara
# Processing Record 5 of Set 2 | voh
# Processing Record 6 of Set 2 | rincon
# Processing Record 7 of Set 2 | bagheria
# Processing Record 8 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 2 | castro
# Processing Record 10 of Set 2 | big spring
# Processing Record 11 of Set 2 | meulaboh
# Processing Record 12 of Set 2 | albany
# Processing Record 13 of Set 2 | upernavik
# Processing Record 14 of Set 2 | adrar
# Processing Record 15 of Set 2 | tilichiki
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | atbasar
# Processing Record 18 of Set 2 | mataura
# Processing Record 19 of Set 2 | ranau
# Processing Record 20 of Set 2 | talnakh
# Processing Record 21 of Set 2 | punta arenas
# Processing Record 22 of Set 2 | nikolskoye
# Processing Record 23 of Set 2 | tiarei
# Processing Record 24 of Set 2 | arraial do cabo
# Processing Record 25 of Set 2 | quatre cocos
# Processing Record 26 of Set 2 | puerto ayora
# Processing Record 27 of Set 2 | abnub
# Processing Record 28 of Set 2 | sobolevo
# Processing Record 29 of Set 2 | manbij
# Processing Record 30 of Set 2 | kruisfontein
# Processing Record 31 of Set 2 | longyearbyen
# Processing Record 32 of Set 2 | ishigaki
# Processing Record 33 of Set 2 | ordzhonikidze
# Processing Record 34 of Set 2 | izhma
# Processing Record 35 of Set 2 | potosi
# Processing Record 36 of Set 2 | luanda
# Processing Record 37 of Set 2 | constitucion
# Processing Record 38 of Set 2 | port macquarie
# Processing Record 39 of Set 2 | saint george
# Processing Record 40 of Set 2 | kintinku
# Processing Record 41 of Set 2 | kaeo
# Processing Record 42 of Set 2 | puerto el triunfo
# Processing Record 43 of Set 2 | yambio
# Processing Record 44 of Set 2 | karratha
# Processing Record 45 of Set 2 | sambava
# Processing Record 46 of Set 2 | cidreira
# Processing Record 47 of Set 2 | fortuna
# Processing Record 48 of Set 2 | plettenberg bay
# Processing Record 49 of Set 2 | trairi
# Processing Record 50 of Set 2 | grand gaube
# Processing Record 1 of Set 3 | flinders
# Processing Record 2 of Set 3 | sibut
# Processing Record 3 of Set 3 | ladozhskaya
# Processing Record 4 of Set 3 | amazar
# Processing Record 5 of Set 3 | bonavista
# Processing Record 6 of Set 3 | serebryansk
# Processing Record 7 of Set 3 | ambilobe
# Processing Record 8 of Set 3 | port lincoln
# Processing Record 9 of Set 3 | namibe
# Processing Record 10 of Set 3 | port elizabeth
# Processing Record 11 of Set 3 | yulara
# Processing Record 12 of Set 3 | mikhaylov
# Processing Record 13 of Set 3 | vaini
# Processing Record 14 of Set 3 | ostrovnoy
# Processing Record 15 of Set 3 | rocha
# Processing Record 16 of Set 3 | chokurdakh
# Processing Record 17 of Set 3 | utiroa
# City not found. Skipping...
# Processing Record 18 of Set 3 | hilo
# Processing Record 19 of Set 3 | xuddur
# Processing Record 20 of Set 3 | along
# Processing Record 21 of Set 3 | sur
# Processing Record 22 of Set 3 | ourossogui
# Processing Record 23 of Set 3 | salinopolis
# Processing Record 24 of Set 3 | sao gabriel da cachoeira
# Processing Record 25 of Set 3 | ahipara
# Processing Record 26 of Set 3 | khor
# Processing Record 27 of Set 3 | chuy
# Processing Record 28 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 29 of Set 3 | torbay
# Processing Record 30 of Set 3 | bam
# Processing Record 31 of Set 3 | yellowknife
# Processing Record 32 of Set 3 | camacha
# Processing Record 33 of Set 3 | taltal
# Processing Record 34 of Set 3 | hithadhoo
# Processing Record 35 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 36 of Set 3 | nyurba
# Processing Record 37 of Set 3 | nuevo progreso
# Processing Record 38 of Set 3 | georgetown
# Processing Record 39 of Set 3 | atuona
# Processing Record 40 of Set 3 | ponta do sol
# Processing Record 41 of Set 3 | nome
# Processing Record 42 of Set 3 | ancud
# Processing Record 43 of Set 3 | kununurra
# Processing Record 44 of Set 3 | sao filipe
# Processing Record 45 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 46 of Set 3 | bambous virieux
# Processing Record 47 of Set 3 | kismayo
# Processing Record 48 of Set 3 | vilnius
# Processing Record 49 of Set 3 | kokopo
# Processing Record 50 of Set 3 | wisconsin rapids
# Processing Record 1 of Set 4 | thompson
# Processing Record 2 of Set 4 | acapulco
# Processing Record 3 of Set 4 | vanimo
# Processing Record 4 of Set 4 | barpeta
# Processing Record 5 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 4 | eydhafushi
# Processing Record 7 of Set 4 | arlit
# Processing Record 8 of Set 4 | jamtara
# Processing Record 9 of Set 4 | lavrentiya
# Processing Record 10 of Set 4 | faanui
# Processing Record 11 of Set 4 | keetmanshoop
# Processing Record 12 of Set 4 | kapaa
# Processing Record 13 of Set 4 | ugoofaaru
# Processing Record 14 of Set 4 | pevek
# Processing Record 15 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 4 | dakar
# Processing Record 17 of Set 4 | san miguel
# Processing Record 18 of Set 4 | saint-georges
# Processing Record 19 of Set 4 | zhangye
# Processing Record 20 of Set 4 | tuktoyaktuk
# Processing Record 21 of Set 4 | pomabamba
# Processing Record 22 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 23 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 24 of Set 4 | constantine
# Processing Record 25 of Set 4 | kaitangata
# Processing Record 26 of Set 4 | sebu
# Processing Record 27 of Set 4 | alcanede
# Processing Record 28 of Set 4 | baykit
# Processing Record 29 of Set 4 | tadine
# Processing Record 30 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 4 | mattru
# Processing Record 32 of Set 4 | buchanan
# Processing Record 33 of Set 4 | glendive
# Processing Record 34 of Set 4 | cabo san lucas
# Processing Record 35 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 4 | east london
# Processing Record 37 of Set 4 | bengkulu
# Processing Record 38 of Set 4 | rundu
# Processing Record 39 of Set 4 | saurimo
# Processing Record 40 of Set 4 | mpika
# Processing Record 41 of Set 4 | ribeira grande
# Processing Record 42 of Set 4 | mahibadhoo
# Processing Record 43 of Set 4 | gejiu
# Processing Record 44 of Set 4 | surt
# Processing Record 45 of Set 4 | mecca
# Processing Record 46 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 4 | puro
# Processing Record 48 of Set 4 | saint-pierre
# Processing Record 49 of Set 4 | yerbogachen
# Processing Record 50 of Set 4 | fairbanks
# Processing Record 1 of Set 5 | belaya gora
# Processing Record 2 of Set 5 | san juan
# Processing Record 3 of Set 5 | bubaque
# Processing Record 4 of Set 5 | okha
# Processing Record 5 of Set 5 | bethel
# Processing Record 6 of Set 5 | bredasdorp
# Processing Record 7 of Set 5 | sindor
# Processing Record 8 of Set 5 | opuwo
# Processing Record 9 of Set 5 | tomatlan
# Processing Record 10 of Set 5 | anantapur
# Processing Record 11 of Set 5 | san patricio
# Processing Record 12 of Set 5 | kloulklubed
# Processing Record 13 of Set 5 | gap
# Processing Record 14 of Set 5 | katsuura
# Processing Record 15 of Set 5 | batticaloa
# Processing Record 16 of Set 5 | okhotsk
# Processing Record 17 of Set 5 | pontes e lacerda
# Processing Record 18 of Set 5 | dingle
# Processing Record 19 of Set 5 | sangmelima
# Processing Record 20 of Set 5 | lekoni
# Processing Record 21 of Set 5 | tura
# Processing Record 22 of Set 5 | griffith
# Processing Record 23 of Set 5 | mar del plata
# Processing Record 24 of Set 5 | lubaczow
# Processing Record 25 of Set 5 | kodiak
# Processing Record 26 of Set 5 | emba
# Processing Record 27 of Set 5 | dhidhdhoo
# Processing Record 28 of Set 5 | sloboda
# Processing Record 29 of Set 5 | jiaxing
# Processing Record 30 of Set 5 | codrington
# Processing Record 31 of Set 5 | qaanaaq
# Processing Record 32 of Set 5 | narsaq
# Processing Record 33 of Set 5 | kavaratti
# Processing Record 34 of Set 5 | samaca
# Processing Record 35 of Set 5 | mutsamudu
# City not found. Skipping...
# Processing Record 36 of Set 5 | pitimbu
# Processing Record 37 of Set 5 | neftcala
# Processing Record 38 of Set 5 | klaksvik
# Processing Record 39 of Set 5 | los andes
# Processing Record 40 of Set 5 | joao pinheiro
# Processing Record 41 of Set 5 | carutapera
# Processing Record 42 of Set 5 | cayenne
# Processing Record 43 of Set 5 | whitianga
# Processing Record 44 of Set 5 | belyy yar
# Processing Record 45 of Set 5 | severo-kurilsk
# Processing Record 46 of Set 5 | mehamn
# Processing Record 47 of Set 5 | pinheiro machado
# Processing Record 48 of Set 5 | hervey bay
# Processing Record 49 of Set 5 | san ramon
# Processing Record 50 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 1 of Set 6 | duz
# City not found. Skipping...
# Processing Record 2 of Set 6 | la ronge
# Processing Record 3 of Set 6 | sao felix do xingu
# Processing Record 4 of Set 6 | mastic beach
# Processing Record 5 of Set 6 | arrecife
# Processing Record 6 of Set 6 | ulladulla
# Processing Record 7 of Set 6 | pierre
# Processing Record 8 of Set 6 | parrita
# Processing Record 9 of Set 6 | flin flon
# Processing Record 10 of Set 6 | lebu
# Processing Record 11 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 6 | dicabisagan
# Processing Record 13 of Set 6 | riyadh
# Processing Record 14 of Set 6 | port blair
# Processing Record 15 of Set 6 | airai
# Processing Record 16 of Set 6 | narrabri
# Processing Record 17 of Set 6 | kavieng
# Processing Record 18 of Set 6 | leningradskiy
# Processing Record 19 of Set 6 | terrasini
# Processing Record 20 of Set 6 | monroe
# Processing Record 21 of Set 6 | yar-sale
# Processing Record 22 of Set 6 | tessalit
# Processing Record 23 of Set 6 | cabedelo
# Processing Record 24 of Set 6 | fushan
# Processing Record 25 of Set 6 | provideniya
# Processing Record 26 of Set 6 | dikson
# Processing Record 27 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 6 | pilar
# Processing Record 29 of Set 6 | kegayli
# City not found. Skipping...
# Processing Record 30 of Set 6 | taoudenni
# Processing Record 31 of Set 6 | ogulin
# Processing Record 32 of Set 6 | haines junction
# Processing Record 33 of Set 6 | hami
# Processing Record 34 of Set 6 | anchorage
# Processing Record 35 of Set 6 | portland
# Processing Record 36 of Set 6 | nara
# Processing Record 37 of Set 6 | inhambane
# Processing Record 38 of Set 6 | vestmannaeyjar
# Processing Record 39 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 6 | vardo
# Processing Record 41 of Set 6 | mount gambier
# Processing Record 42 of Set 6 | mount isa
# Processing Record 43 of Set 6 | vagur
# Processing Record 44 of Set 6 | jejuri
# Processing Record 45 of Set 6 | wucheng
# Processing Record 46 of Set 6 | fenoarivo
# Processing Record 47 of Set 6 | le havre
# Processing Record 48 of Set 6 | solnechnyy
# Processing Record 49 of Set 6 | berdigestyakh
# Processing Record 50 of Set 6 | businga
# Processing Record 1 of Set 7 | sitka
# Processing Record 2 of Set 7 | malpe
# Processing Record 3 of Set 7 | roald
# Processing Record 4 of Set 7 | pangnirtung
# Processing Record 5 of Set 7 | port-gentil
# Processing Record 6 of Set 7 | whitehorse
# Processing Record 7 of Set 7 | solsvik
# City not found. Skipping...
# Processing Record 8 of Set 7 | san felipe
# Processing Record 9 of Set 7 | souillac
# Processing Record 10 of Set 7 | zomergem
# Processing Record 11 of Set 7 | grand island
# Processing Record 12 of Set 7 | walvis bay
# Processing Record 13 of Set 7 | lakes entrance
# Processing Record 14 of Set 7 | lompoc
# Processing Record 15 of Set 7 | naze
# Processing Record 16 of Set 7 | saldanha
# Processing Record 17 of Set 7 | abapo
# Processing Record 18 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 19 of Set 7 | coquimbo
# Processing Record 20 of Set 7 | stolin
# Processing Record 21 of Set 7 | waingapu
# Processing Record 22 of Set 7 | mankono
# Processing Record 23 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 7 | eyl
# Processing Record 26 of Set 7 | presidencia roque saenz pena
# Processing Record 27 of Set 7 | pandan
# Processing Record 28 of Set 7 | liverpool
# Processing Record 29 of Set 7 | srednekolymsk
# Processing Record 30 of Set 7 | gunjur
# Processing Record 31 of Set 7 | wanning
# Processing Record 32 of Set 7 | salalah
# Processing Record 33 of Set 7 | isangel
# Processing Record 34 of Set 7 | margate
# Processing Record 35 of Set 7 | aquiraz
# Processing Record 36 of Set 7 | ambon
# Processing Record 37 of Set 7 | sainte-anne-des-monts
# Processing Record 38 of Set 7 | itarema
# Processing Record 39 of Set 7 | omsk
# Processing Record 40 of Set 7 | sicamous
# Processing Record 41 of Set 7 | rio gallegos
# Processing Record 42 of Set 7 | chippewa falls
# Processing Record 43 of Set 7 | bac lieu
# Processing Record 44 of Set 7 | markha
# Processing Record 45 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 7 | volksrust
# Processing Record 47 of Set 7 | siderno
# Processing Record 48 of Set 7 | lasa
# Processing Record 49 of Set 7 | norman wells
# Processing Record 50 of Set 7 | lucea
# Processing Record 1 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 8 | yarkovo
# Processing Record 3 of Set 8 | zhigansk
# Processing Record 4 of Set 8 | serrinha
# Processing Record 5 of Set 8 | antofagasta
# Processing Record 6 of Set 8 | yangliuqing
# Processing Record 7 of Set 8 | edendale
# Processing Record 8 of Set 8 | kyra
# Processing Record 9 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 8 | tallahassee
# Processing Record 11 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 8 | mirnyy
# Processing Record 13 of Set 8 | luderitz
# Processing Record 14 of Set 8 | vila franca do campo
# Processing Record 15 of Set 8 | deputatskiy
# Processing Record 16 of Set 8 | paliyad
# Processing Record 17 of Set 8 | kashi
# Processing Record 18 of Set 8 | yurimaguas
# Processing Record 19 of Set 8 | hornepayne
# Processing Record 20 of Set 8 | raga
# Processing Record 21 of Set 8 | boa vista
# Processing Record 22 of Set 8 | cockburn town
# Processing Record 23 of Set 8 | pochutla
# Processing Record 24 of Set 8 | honiton
# Processing Record 25 of Set 8 | esperance
# Processing Record 26 of Set 8 | santiago del estero
# Processing Record 27 of Set 8 | diamantino
# Processing Record 28 of Set 8 | san rafael
# Processing Record 29 of Set 8 | alta floresta
# Processing Record 30 of Set 8 | kendari
# Processing Record 31 of Set 8 | weatherford
# Processing Record 32 of Set 8 | andenes
# Processing Record 33 of Set 8 | buluang
# Processing Record 34 of Set 8 | praia da vitoria
# Processing Record 35 of Set 8 | chapais
# Processing Record 36 of Set 8 | pauini
# Processing Record 37 of Set 8 | poya
# Processing Record 38 of Set 8 | mandera
# Processing Record 39 of Set 8 | hirara
# Processing Record 40 of Set 8 | mooi river
# City not found. Skipping...
# Processing Record 41 of Set 8 | san angelo
# Processing Record 42 of Set 8 | jiayuguan
# Processing Record 43 of Set 8 | yozgat
# Processing Record 44 of Set 8 | caravelas
# Processing Record 45 of Set 8 | revda
# Processing Record 46 of Set 8 | verkhnevilyuysk
# Processing Record 47 of Set 8 | yirol
# City not found. Skipping...
# Processing Record 48 of Set 8 | guerrero negro
# Processing Record 49 of Set 8 | embonas
# Processing Record 50 of Set 8 | aklavik
# Processing Record 1 of Set 9 | kardailovo
# Processing Record 2 of Set 9 | stornoway
# Processing Record 3 of Set 9 | grafton
# Processing Record 4 of Set 9 | nioro
# Processing Record 5 of Set 9 | ouesso
# Processing Record 6 of Set 9 | mujiayingzi
# Processing Record 7 of Set 9 | vestbygda
# City not found. Skipping...
# Processing Record 8 of Set 9 | novikovo
# Processing Record 9 of Set 9 | dongsheng
# Processing Record 10 of Set 9 | qaqortoq
# Processing Record 11 of Set 9 | husavik
# Processing Record 12 of Set 9 | kudahuvadhoo
# Processing Record 13 of Set 9 | kontagora
# Processing Record 14 of Set 9 | urucui
# Processing Record 15 of Set 9 | bellmead
# Processing Record 16 of Set 9 | ukiah
# Processing Record 17 of Set 9 | rawah
# Processing Record 18 of Set 9 | yeppoon
# Processing Record 19 of Set 9 | nampula
# Processing Record 20 of Set 9 | mildura
# Processing Record 21 of Set 9 | rafai
# Processing Record 22 of Set 9 | nouakchott
# Processing Record 23 of Set 9 | algodones
# Processing Record 24 of Set 9 | koslan
# Processing Record 25 of Set 9 | san andres
# Processing Record 26 of Set 9 | dhule
# Processing Record 27 of Set 9 | qasigiannguit
# Processing Record 28 of Set 9 | tupik
# Processing Record 29 of Set 9 | falealupo
# City not found. Skipping...
# Processing Record 30 of Set 9 | uwajima
# Processing Record 31 of Set 9 | iqaluit
# Processing Record 32 of Set 9 | milingimbi
# City not found. Skipping...
# Processing Record 33 of Set 9 | aseri
# Processing Record 34 of Set 9 | te anau
# Processing Record 35 of Set 9 | nador
# Processing Record 36 of Set 9 | tautira
# Processing Record 37 of Set 9 | laguna
# Processing Record 38 of Set 9 | akkermanovka
# Processing Record 39 of Set 9 | porto novo
# Processing Record 40 of Set 9 | port hueneme
# Processing Record 41 of Set 9 | baracoa
# Processing Record 42 of Set 9 | samarai
# Processing Record 43 of Set 9 | tommot
# Processing Record 44 of Set 9 | wagar
# Processing Record 45 of Set 9 | oppdal
# Processing Record 46 of Set 9 | ust-nera
# Processing Record 47 of Set 9 | romans-sur-isere
# Processing Record 48 of Set 9 | westport
# Processing Record 49 of Set 9 | kargil
# Processing Record 50 of Set 9 | forio
# Processing Record 1 of Set 10 | hofn
# Processing Record 2 of Set 10 | bathsheba
# Processing Record 3 of Set 10 | celestun
# Processing Record 4 of Set 10 | oudtshoorn
# Processing Record 5 of Set 10 | tuatapere
# Processing Record 6 of Set 10 | dalaba
# Processing Record 7 of Set 10 | ziro
# Processing Record 8 of Set 10 | taunton
# Processing Record 9 of Set 10 | north bend
# Processing Record 10 of Set 10 | idar
# Processing Record 11 of Set 10 | tabialan
# City not found. Skipping...
# Processing Record 12 of Set 10 | kita
# Processing Record 13 of Set 10 | kenai
# Processing Record 14 of Set 10 | sisimiut
# Processing Record 15 of Set 10 | manzhouli
# Processing Record 16 of Set 10 | ulaanbaatar
# Processing Record 17 of Set 10 | tazovskiy
# Processing Record 18 of Set 10 | siguiri
# Processing Record 19 of Set 10 | ampanihy
# Processing Record 20 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 21 of Set 10 | sechura
# Processing Record 22 of Set 10 | neiafu
# Processing Record 23 of Set 10 | ust-maya
# Processing Record 24 of Set 10 | bonnyville
# Processing Record 25 of Set 10 | komsomolets
# Processing Record 26 of Set 10 | wexford
# Processing Record 27 of Set 10 | mackay
# Processing Record 28 of Set 10 | victoria
# Processing Record 29 of Set 10 | saint-joseph
# Processing Record 30 of Set 10 | saint anthony
# Processing Record 31 of Set 10 | ziarat
# Processing Record 32 of Set 10 | ovsyanka
# Processing Record 33 of Set 10 | gariaband
# Processing Record 34 of Set 10 | cap malheureux
# Processing Record 35 of Set 10 | burnie
# Processing Record 36 of Set 10 | noumea
# Processing Record 37 of Set 10 | hasaki
# Processing Record 38 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 10 | nivala
# Processing Record 40 of Set 10 | gryazovets
# Processing Record 41 of Set 10 | olafsvik
# Processing Record 42 of Set 10 | sancel
# Processing Record 43 of Set 10 | touba
# Processing Record 44 of Set 10 | clyde river
# Processing Record 45 of Set 10 | aguachica
# Processing Record 46 of Set 10 | tukrah
# Processing Record 47 of Set 10 | hainichen
# Processing Record 48 of Set 10 | tuy hoa
# Processing Record 49 of Set 10 | orlik
# Processing Record 50 of Set 10 | dandong
# Processing Record 1 of Set 11 | krasnoshchekovo
# Processing Record 2 of Set 11 | camalu
# Processing Record 3 of Set 11 | iracoubo
# Processing Record 4 of Set 11 | lagoa
# Processing Record 5 of Set 11 | chunskiy
# Processing Record 6 of Set 11 | raudeberg
# Processing Record 7 of Set 11 | guilin
# Processing Record 8 of Set 11 | mugur-aksy
# Processing Record 9 of Set 11 | utete
# Processing Record 10 of Set 11 | epernay
# Processing Record 11 of Set 11 | dashitou
# Processing Record 12 of Set 11 | ray
# Processing Record 13 of Set 11 | sao joao da barra
# Processing Record 14 of Set 11 | maragogi
# Processing Record 15 of Set 11 | beihai
# Processing Record 16 of Set 11 | sola
# Processing Record 17 of Set 11 | stonewall
# Processing Record 18 of Set 11 | santa rita
# Processing Record 19 of Set 11 | vicksburg
# Processing Record 20 of Set 11 | weihe
# Processing Record 21 of Set 11 | prince rupert
# Processing Record 22 of Set 11 | de-kastri
# Processing Record 23 of Set 11 | hobyo
# Processing Record 24 of Set 11 | fort nelson
# Processing Record 25 of Set 11 | mundo nuevo
# Processing Record 26 of Set 11 | kirakira
# Processing Record 27 of Set 11 | winneba
# Processing Record 28 of Set 11 | san borja
# Processing Record 29 of Set 11 | macas
# Processing Record 30 of Set 11 | payson
# Processing Record 31 of Set 11 | pedasi
# Processing Record 32 of Set 11 | svetlyy
# Processing Record 33 of Set 11 | tooele
# Processing Record 34 of Set 11 | sao domingos do maranhao
# Processing Record 35 of Set 11 | zvishavane
# Processing Record 36 of Set 11 | salta
# Processing Record 37 of Set 11 | racine
# Processing Record 38 of Set 11 | sandwick
# Processing Record 39 of Set 11 | torrington
# Processing Record 40 of Set 11 | lloydminster
# Processing Record 41 of Set 11 | japura
# Processing Record 42 of Set 11 | hovd
# Processing Record 43 of Set 11 | nakanojo
# Processing Record 44 of Set 11 | aden
# Processing Record 45 of Set 11 | stuttgart
# Processing Record 46 of Set 11 | marfino
# Processing Record 47 of Set 11 | chishtian mandi
# Processing Record 48 of Set 11 | selikhino
# Processing Record 49 of Set 11 | hambantota
# Processing Record 50 of Set 11 | maningrida
# Processing Record 1 of Set 12 | amapa
# Processing Record 2 of Set 12 | shakawe
# Processing Record 3 of Set 12 | biak
# Processing Record 4 of Set 12 | elizabeth city
# Processing Record 5 of Set 12 | yelanskiy
# Processing Record 6 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 7 of Set 12 | chapeco
# Processing Record 8 of Set 12 | mantua
# Processing Record 9 of Set 12 | minas de barroteran
# Processing Record 10 of Set 12 | buta
# Processing Record 11 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 12 of Set 12 | bolshoye nagatkino
# Processing Record 13 of Set 12 | angoche
# Processing Record 14 of Set 12 | bairiki
# Processing Record 15 of Set 12 | sofiysk
# City not found. Skipping...
# Processing Record 16 of Set 12 | koutsouras
# Processing Record 17 of Set 12 | gubin
# Processing Record 18 of Set 12 | asau
# Processing Record 19 of Set 12 | erenhot
# Processing Record 20 of Set 12 | nelson bay
# Processing Record 21 of Set 12 | namatanai
# Processing Record 22 of Set 12 | tambun
# Processing Record 23 of Set 12 | wajir
# Processing Record 24 of Set 12 | lata
# Processing Record 25 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 26 of Set 12 | port moresby
# Processing Record 27 of Set 12 | lucapa
# Processing Record 28 of Set 12 | marang
# Processing Record 29 of Set 12 | chihuahua
# Processing Record 30 of Set 12 | moberly
# Processing Record 31 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 32 of Set 12 | vila
# Processing Record 33 of Set 12 | zhaodong
# Processing Record 34 of Set 12 | belousovka
# Processing Record 35 of Set 12 | damara
# Processing Record 36 of Set 12 | onega
# Processing Record 37 of Set 12 | dunedin
# Processing Record 38 of Set 12 | deneysville
# Processing Record 39 of Set 12 | sarangani
# Processing Record 40 of Set 12 | nisia floresta
# Processing Record 41 of Set 12 | nova gradiska
# Processing Record 42 of Set 12 | vila do maio
# Processing Record 43 of Set 12 | oksfjord
# Processing Record 44 of Set 12 | bentiu
# Processing Record 45 of Set 12 | kalmunai
# Processing Record 46 of Set 12 | saint-augustin
# Processing Record 47 of Set 12 | abu zabad
# Processing Record 48 of Set 12 | san cristobal
# Processing Record 49 of Set 12 | toktogul
# Processing Record 50 of Set 12 | kutum
# Processing Record 1 of Set 13 | sandnessjoen
# Processing Record 2 of Set 13 | minab
# Processing Record 3 of Set 13 | buncrana
# Processing Record 4 of Set 13 | montoro
# Processing Record 5 of Set 13 | xining
# Processing Record 6 of Set 13 | markapur
# Processing Record 7 of Set 13 | mendeleyevsk
# Processing Record 8 of Set 13 | jaen
# Processing Record 9 of Set 13 | itum-kale
# Processing Record 10 of Set 13 | shawnee
# Processing Record 11 of Set 13 | katobu
# Processing Record 12 of Set 13 | sao lourenco do sul
# Processing Record 13 of Set 13 | mozhaysk
# Processing Record 14 of Set 13 | taikang
# Processing Record 15 of Set 13 | derzhavinsk
# Processing Record 16 of Set 13 | grindavik
# Processing Record 17 of Set 13 | copala
# Processing Record 18 of Set 13 | vao
# Processing Record 19 of Set 13 | leopold
# Processing Record 20 of Set 13 | anadyr
# Processing Record 21 of Set 13 | jutai
# Processing Record 22 of Set 13 | xingyi
# Processing Record 23 of Set 13 | oranjemund
# Processing Record 24 of Set 13 | katherine
# Processing Record 25 of Set 13 | byron bay
# Processing Record 26 of Set 13 | umm lajj
# Processing Record 27 of Set 13 | darhan
# Processing Record 28 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 29 of Set 13 | palmares do sul
# Processing Record 30 of Set 13 | dawlatabad
# Processing Record 31 of Set 13 | moron
# Processing Record 32 of Set 13 | tres picos
# Processing Record 33 of Set 13 | maumere
# Processing Record 34 of Set 13 | erzin
# Processing Record 35 of Set 13 | touros
# Processing Record 36 of Set 13 | pedernales
# Processing Record 37 of Set 13 | kabalo
# Processing Record 38 of Set 13 | vallenar
# Processing Record 39 of Set 13 | ramhormoz
# Processing Record 40 of Set 13 | woodland
# Processing Record 41 of Set 13 | roverud
# Processing Record 42 of Set 13 | ballina
# Processing Record 43 of Set 13 | korla
# Processing Record 44 of Set 13 | grandola
# Processing Record 45 of Set 13 | takoradi
# Processing Record 46 of Set 13 | acari
# Processing Record 47 of Set 13 | havelock
# Processing Record 48 of Set 13 | khandyga
# Processing Record 49 of Set 13 | smidovich
# Processing Record 50 of Set 13 | bontang
# Processing Record 1 of Set 14 | myingyan
# Processing Record 2 of Set 14 | mgandu
# Processing Record 3 of Set 14 | muros
# Processing Record 4 of Set 14 | atherton
# Processing Record 5 of Set 14 | birsk
# Processing Record 6 of Set 14 | barranca
# Processing Record 7 of Set 14 | buala
# Processing Record 8 of Set 14 | honiara
# Processing Record 9 of Set 14 | svobodnyy
# Processing Record 10 of Set 14 | katsiveli
# City not found. Skipping...
# Processing Record 11 of Set 14 | coahuayana
# Processing Record 12 of Set 14 | santa rosalia
# Processing Record 13 of Set 14 | mayumba
# Processing Record 14 of Set 14 | matale
# Processing Record 15 of Set 14 | caluquembe
# Processing Record 16 of Set 14 | tual
# Processing Record 17 of Set 14 | holme
# Processing Record 18 of Set 14 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 19 of Set 14 | bambari
# Processing Record 20 of Set 14 | fenton
# Processing Record 21 of Set 14 | vulcan
# Processing Record 22 of Set 14 | santa rosa
# Processing Record 23 of Set 14 | kallithea
# Processing Record 24 of Set 14 | beringovskiy
# Processing Record 25 of Set 14 | oktyabrskoye
# Processing Record 26 of Set 14 | koudougou
# Processing Record 27 of Set 14 | caohai
# Processing Record 28 of Set 14 | havre
# Processing Record 29 of Set 14 | seara
# Processing Record 30 of Set 14 | capreol
# Processing Record 31 of Set 14 | issoudun
# Processing Record 32 of Set 14 | preobrazheniye
# Processing Record 33 of Set 14 | northam
# Processing Record 34 of Set 14 | suihua
# Processing Record 35 of Set 14 | bowen
# Processing Record 36 of Set 14 | nizhnyaya tavda
# Processing Record 37 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 14 | evensk
# Processing Record 39 of Set 14 | iskateley
# Processing Record 40 of Set 14 | lossiemouth
# Processing Record 41 of Set 14 | beloha
# Processing Record 42 of Set 14 | chara
# Processing Record 43 of Set 14 | ozark
# Processing Record 44 of Set 14 | egvekinot
# Processing Record 45 of Set 14 | taburao
# City not found. Skipping...
# Processing Record 46 of Set 14 | buraydah
# Processing Record 47 of Set 14 | sapao
# City not found. Skipping...
# Processing Record 48 of Set 14 | rostovka
# Processing Record 49 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 50 of Set 14 | ginda
# Processing Record 1 of Set 15 | zuwarah
# Processing Record 2 of Set 15 | werda
# Processing Record 3 of Set 15 | weligama
# Processing Record 4 of Set 15 | poum
# Processing Record 5 of Set 15 | paka
# Processing Record 6 of Set 15 | severodvinsk
# Processing Record 7 of Set 15 | do gonbadan
# Processing Record 8 of Set 15 | vila velha
# Processing Record 9 of Set 15 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 15 | longyan
# Processing Record 11 of Set 15 | shelburne
# Processing Record 12 of Set 15 | senmonorom
# City not found. Skipping...
# Processing Record 13 of Set 15 | yangjiang
# Processing Record 14 of Set 15 | bani
# Processing Record 15 of Set 15 | jadu
# Processing Record 16 of Set 15 | sistranda
# Processing Record 17 of Set 15 | hauterive
# Processing Record 18 of Set 15 | napier
# Processing Record 19 of Set 15 | mackenzie
# Processing Record 20 of Set 15 | manosque
# Processing Record 21 of Set 15 | novyy urengoy
# Processing Record 22 of Set 15 | makakilo city
# Processing Record 23 of Set 15 | ulaangom
# Processing Record 24 of Set 15 | gamba
# Processing Record 25 of Set 15 | mombetsu
# Processing Record 26 of Set 15 | doka
# Processing Record 27 of Set 15 | jian
# Processing Record 28 of Set 15 | padang
# Processing Record 29 of Set 15 | strai
# Processing Record 30 of Set 15 | puerto del rosario
# Processing Record 31 of Set 15 | kulu
# Processing Record 32 of Set 15 | dzilam gonzalez
# Processing Record 33 of Set 15 | yumen
# Processing Record 34 of Set 15 | kapchorwa
# Processing Record 35 of Set 15 | corpus christi
# Processing Record 36 of Set 15 | murray bridge
# Processing Record 37 of Set 15 | newport
# Processing Record 38 of Set 15 | abu jubayhah
# City not found. Skipping...
# Processing Record 39 of Set 15 | kangaba
# Processing Record 40 of Set 15 | lima
# Processing Record 41 of Set 15 | nouadhibou
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 688

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df =  pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Jalu  29.0331   21.5482     65.23        54         100
# 1      Srandakan  -7.9386  110.2506     74.62        92         100
# 2       Tasiilaq  65.6145  -37.6368     23.68        62         100
# 3     Santa Cruz -17.8000  -63.1667    104.05        20           4
# 4      Geraldton -28.7667  114.6000     59.41        82           4
# 5       Udachnyy  66.4167  112.4000    -22.56        74         100
# 6  Pacific Grove  36.6177 -121.9166     67.39        56           1
# 7      Cape Town -33.9258   18.4232     64.27        66          20
# 8    Port Alfred -33.5906   26.8910     62.19        90          61
# 9       Lorengau  -2.0226  147.2712     81.16        72          28
#
#    Wind Speed Current Description Country                 Date
# 0        8.03     overcast clouds      LY  2022-11-26 19:56:13
# 1        5.95          light rain      ID  2022-11-26 19:58:39
# 2        6.11     overcast clouds      GL  2022-11-26 19:54:51
# 3       14.97           clear sky      BO  2022-11-26 19:56:38
# 4        8.05           clear sky      AU  2022-11-26 19:58:40
# 5        4.32     overcast clouds      RU  2022-11-26 19:56:09
# 6       11.99           clear sky      US  2022-11-26 19:57:40
# 7       21.85          few clouds      ZA  2022-11-26 19:53:38
# 8        3.60       broken clouds      ZA  2022-11-26 19:54:51
# 9        6.04    scattered clouds      PG  2022-11-26 19:58:40

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description', 'Country', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# Recreate the DataFrame by using the new column order
city_data_no_date_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']]

# Display sample data
city_data_no_date_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Jalu      LY  29.0331   21.5482     65.23        54         100
# 1      Srandakan      ID  -7.9386  110.2506     74.62        92         100
# 2       Tasiilaq      GL  65.6145  -37.6368     23.68        62         100
# 3     Santa Cruz      BO -17.8000  -63.1667    104.05        20           4
# 4      Geraldton      AU -28.7667  114.6000     59.41        82           4
# 5       Udachnyy      RU  66.4167  112.4000    -22.56        74         100
# 6  Pacific Grove      US  36.6177 -121.9166     67.39        56           1
# 7      Cape Town      ZA -33.9258   18.4232     64.27        66          20
# 8    Port Alfred      ZA -33.5906   26.8910     62.19        90          61
# 9       Lorengau      PG  -2.0226  147.2712     81.16        72          28
#
#    Wind Speed Current Description
# 0        8.03     overcast clouds
# 1        5.95          light rain
# 2        6.11     overcast clouds
# 3       14.97           clear sky
# 4        8.05           clear sky
# 5        4.32     overcast clouds
# 6       11.99           clear sky
# 7       21.85          few clouds
# 8        3.60       broken clouds
# 9        6.04    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_no_date_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# Export the city_data DataFrame into a CSV file
city_data_no_date_df.to_csv("WeatherPy_Database.csv", index_label="City_ID")
